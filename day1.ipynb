# %%
print("hello tanmayee")
# Out:
# hello tanmayee

# %%
a=10
b=20
a+b
# Out:
# 30

# %%
print(a+b)
# Out:
# 30

# %%
name='Tanmayee'
age=22
mob=2234.5
print(type(name))
print(type(age))
print(type(mob))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
a=10.5
a
# Out:
# 10.5

# %%
int(a)
# Out:
# 10
