# %%
lst=[10,20,30,40,50]

# %%
lst[1]
# Out:
# 20

# %%
lst.insert(2, 60)
lst
# Out:
# [10, 20, 60, 60, 30, 40, 50]

# %%
dic={"name":"Tanmayee","Deg":"B,tech"}

# %%
dic['name']
# Out:
# 'Tanmayee'

# %%
dic.get("Deg")
# Out:
# 'B,tech'

# %%
lst[1:3] #range of index  start:end
# Out:
# [20, 30]

# %%
lst[0:8]
# Out:
# [10, 20, 30, 40, 50]

# %%
lst[0:8:2]
# Out:
# [10, 30, 50]

# %%
lst[::]
# Out:
# [10, 20, 30, 40, 50]

# %%
lst.reverse()

# %%
lst
# Out:
# [50, 40, 30, 20, 10]

# %%
lst[::-1]
# Out:
# [50, 40, 30, 20, 10]

# %%
lst[-2]
# Out:
# 40

# %%
lst[-1:-3]
# Out:
# []

# %%
lst[-3:-1]  #end:start
# Out:
# [30, 40]

# %% [markdown]
# diff bet list and array
# diff bet pop and remove
# diff bet del and pop

# %%
tp=(1,2,3,4)

# %%
tp[2]
# Out:
# 3

# %%
tp.count(2)
# Out:
# 1

# %%
st={1,2,3,4,5,6}

# %%
# st[1] unordered list (index operation work krt nhi)

# %%
dict = {"Name":"Tanmayee", "Degree":"B.tech", 1:"abc"} #immutable types as a dic key set kru shkto

# %%
dict["Name"]
# Out:
# 'Tanmayee'

# %%
dict[1]
# Out:
# 'abc'

# %%
lst=[20,40,50,60]
lst
# Out:
# [20, 40, 50, 60]

# %%
lst[0]=40
lst
# Out:
# [40, 40, 50, 60]

# %%
lst[0:2]=[70,80]        #range 
lst
# Out:
# [70, 80, 50, 60]

# %%
lst.pop()
# Out:
# 60

# %%
lst.remove(50)      #diff bet pop and remove

# %%
lst
# Out:
# [70, 80]

# %%
dict2 = {"Name":"Tanmayee", "Degree":"B.tech", 1:"abc"} 
dict2
# Out:
# {'Name': 'Tanmayee', 'Degree': 'B.tech', 1: 'abc'}

# %%
dict2["EN no"]="EN211"
dict2
# Out:
# {'Name': 'Tanmayee', 'Degree': 'B.tech', 1: 'abc', 'EN no': 'EN211'}

# %%
dict2["En no"]="EN21176650"
dict2
# Out:
# {'Name': 'Tanmayee',
#  'Degree': 'B.tech',
#  1: 'abc',
#  'EN no': 'EN211',
#  'En no': 'EN21176650'}

# %%
del dict2['En no'] #delete kryla del kiva pop

# %%
dict2
# Out:
# {'Name': 'Tanmayee', 'Degree': 'B.tech', 1: 'abc', 'EN no': 'EN211'}

# %%
dict3={"location":"Pune"}
dict2.update(dict3)

# %%
dict2
# Out:
# {'Name': 'Tanmayee',
#  'Degree': 'B.tech',
#  1: 'abc',
#  'EN no': 'EN211',
#  'location': 'Pune'}

# %%
dic1={"name":"abc"}
dic2={"name":"xyz"}

# %%
dic1.update(dic2)

# %%
dic1
# Out:
# {'name': 'xyz'}

# %%
dic1.pop("name")
dic1
# Out:
# {}
