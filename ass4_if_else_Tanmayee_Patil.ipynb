# %% [markdown]
# ### 1. Write a program to check if a number is positive.

# %%
num=int(input("Enter the number: "))
if num>0:
    print(f"{num} is Positive")
else:
    print(f"{num} is Negative")
# Out:
# 8 is Positive

# %% [markdown]
# ### 2. Check if a number is even or odd.

# %%
num=int(input("Enter the number: "))
if num%2==0:
    print(f"{num} is Even")
else:
    print(f"{num} is Odd")
# Out:
# 3 is Odd

# %% [markdown]
# ### 3. Check if a person is eligible to vote (age >= 18).

# %%
age=int(input("Enter the Age of Person: "))
if age>=18:
    print("The person is eligible to vote")
else:
    print("The person is not eligible to vote")
# Out:
# The person is eligible to vote

# %% [markdown]
# ### 4. Check if a number is greater than 100.

# %%
num=int(input("Enter the number: "))
if num>100:
    print(f"{num} is greater than 100")
else:
    print(f"{num} is less than 100")
# Out:
# 101 is greater than 100

# %% [markdown]
# ### 5. Print “Adult” if age > 18 else print “Child”.

# %%
age=int(input("Enter the number: "))
if age>18:
    print("Adult")
else:
    print("Child")
# Out:
# Adult

# %% [markdown]
# ### 6. Check if two numbers are equal.

# %%
num1=int(input("Enter the number: "))
num2=int(input("Enter the number: "))
if num1==num2:
    print(f"{num1} and {num2} are equal")
else:
    print(f"{num1} and {num2} are not equal")
# Out:
# 3 and 3 are equal

# %% [markdown]
# ### 7. Check if a number is divisible by 5.

# %%
num=int(input("Enter the number: "))
if num%5==0:
    print(f"{num} is divisible by 5")
else:
    print(f"{num} is not divisible by 5")
# Out:
# 20 is divisible by 5

# %% [markdown]
# ### 8. Check if a string is “hello”.

# %%
str='hello'
if str=='hello':
    print("The string is hello")
else:
    print("The string is not hello")

# %% [markdown]
# ### 9. Print the larger of two numbers.

# %%
num1=int(input("Enter the number: "))
num2=int(input("Enter the number: "))
if num1>num2:
    print(f"{num1} is greater than {num2}")
elif num2>num1:
    print(f"{num2} is greater than {num1}")
else:
    print("Both are equals")
# Out:
# 78 is greater than 45

# %% [markdown]
# ### 10. Check if a number is negative

# %%
num1=int(input("Enter the number: "))
if num1<0:
    print(f"{num1} is negative")
else:
    print(f"{num1} is positive")
# Out:
# -4 is negative

# %% [markdown]
# ### 11. Check if a number is positive, negative, or zero.

# %%
num1=int(input("Enter the number: "))
if num1 <0:
    print(f"{num1} is negative")
elif num1>0:
    print(f"{num1} is positive")
else:
    print(f"{num1} is zero")
# Out:
# 7 is positive

# %% [markdown]
# ### 12. Check if a year is a leap year.

# %%
yr=int(input("Enter the year: "))
if yr%400==0:
    print(f"{yr} is a leap year")
elif yr%100==0:
    print(f"{yr} is not a leap year")
elif yr%4==0:
    print(f"{yr} is a leap year")
else:
    print("Not a leap year")
# Out:
# 200 is not a leap year

# %% [markdown]
# ### 13. Check if a character is a vowel or consonant.

# %%
chr=input("Enter the character: ")
if chr=="a" or chr=="e" or chr=="i" or chr=="o" or chr=="u":
    print(f"{chr} is vowel")
else:
    print(f"{chr} is consonant")
# Out:
# h is consonant

# %% [markdown]
# ### 14. Print the greatest of three numbers.

# %%
num1=int(input("Enter the number: "))
num2=int(input("Enter the number: "))
num3=int(input("Enter the number: "))
if num1>num2 and num1>num3:
    print(f"{num1} is greater")
elif num2>num3 and num2>num1:
    print(f"{num2} is greater")
else:
    print(f"{num3} is greater") #2,7,4
 # OR
# Out:
# 7 is greater

# %%
num1=int(input("Enter the number: "))
num2=int(input("Enter the number: "))
num3=int(input("Enter the number: "))
greater=max(num1,num2,num3)
print(f"{greater} is greater")    #2,7,4
# Out:
# 7 is greater

# %% [markdown]
# ### 15. Check if a password length is strong (>= 8).

# %%
password=(input("Enter the Password: "))
if len(password)>=8:
    print("Strong Password")
else:
    print("Weak Password")
# Out:
# Strong Password

# %% [markdown]
# ### 16. Check if a number lies between 10 and 50.

# %%
num=int(input("Enter the number: "))
if num>10 and num<50:
    print(f"{num} lies between 10 and 50")
else:
    print(f"{num} don't lie between 10 and 50")
# Out:
# 45 lies between 10 and 50

# %% [markdown]
# ### 17. Print the grade of a student (A, B, C, D, F) based on marks.

# %%
marks=int(input("Enter the number: "))
if marks>90:
    print("Grade A")
elif marks>80:
    print("Grade B")
elif marks>70:
    print("Grade C")
elif marks>60:
    print("Grade D")
else:
    print("Grade F")
# Out:
# Grade B

# %% [markdown]
# ### 18. Check if a number is divisible by both 2 and 3.

# %%
num=int(input("Enter the number: "))
if num%2==0 and num%3==0:
    print(f"{num} is divisible by both 2 and 3")
else:
    print(f"{num} is not divisible by both 2 and 3")
# Out:
# 6 is divisible by both 2 and 3

# %% [markdown]
# ### 19. Check if a person’s age falls into categories: child, teen, adult, senior.

# %%
age=int(input("Enter the age of person: "))
if age<12:
    print("Child")
elif age<=18:
    print("Teen")
elif age<=64:
    print("Adult")
else:
    print("Senior")
# Out:
# Adult

# %% [markdown]
# ### 20. Check if a character is uppercase or lowercase.

# %%
chr=input("Enter the character: ")
if chr==chr.lower():
    print("Lowercase")
else:
    print("Uppercase")  #hello
# Out:
# Lowercase

# %% [markdown]
# ### 21. Check if a number is a multiple of 10.

# %%
num=int(input("Enter the number: "))
if num%10==0:
    print(f"{num} is multiple of 10")
else:
    print(f"{num} is not a multiple of 10")
# Out:
# 200 is multiple of 10

# %% [markdown]
# ### 22. Compare two numbers and print “greater”, “smaller”, or “equal”.

# %%
num1=int(input("Enter the number: "))
num2=int(input("Enter the number: "))
if num1>num2:
    print("Greater")
elif num1<num2:
    print("Smaller")
else:
    print("Equal")  # num1=5,num2=4
# Out:
# Greater

# %% [markdown]
# ### 23. Check if a triangle is equilateral, isosceles, or scalene.

# %%
a=float(input("Enter the side a: "))
b=float(input("Enter the side b: "))
c=float(input("Enter the side c: "))
if (a + b > c) and (a + c > b) and (b + c > a):
    if a == b == c:
        print("Equilateral triangle")
    elif a == b or b == c or a == c:
        print("Isosceles triangle")
    else:
        print("Scalene triangle")
else:
    print("Triangle is not valid")        # a=90,b=90,c=90
# Out:
# Equilateral triangle

# %% [markdown]
# ### 24. Check if a string contains the word “python”.

# %%
string=input("Enter the string: ")
if string=="python":
    print("String contains the word Python")
else:
    print("String does not contain python") #python
# Out:
# String contains the word Python

# %% [markdown]
# ### 25. Check if a list has more than 5 elements.

# %%
ls=[1,2,3,4,5,6]
if len(ls)>5:
    print("List contains greater than 5 elements")
else:
    print("List contains less than 5 elements")
# Out:
# List contains greater than 5 elements

# %% [markdown]
# ### 26. Check if temperature is cold (<15), warm (15–30), or hot (>30).

# %%
temp=int(input("Enter the Temperature: "))
if temp<15:
    print("Cold")
elif temp>=15 and temp<=30:
    print("Warm")
else:
    print("Hot")            #temp=18
# Out:
# Warm

# %% [markdown]
# ### 27. Check if a student passed (marks >= 40) else fail.

# %%
marks=int(input("Enter the Temperature: "))
if marks>=40:
    print("Student Passed")
else:
    print("Student Failed")         #marks=70
# Out:
# Student Passed

# %% [markdown]
# ### 28. Check if a number ends with digit 7.

# %%
num=567
if num%10==7:
    print("Number ends with 7")
else:
    print("Number does not end with 7")
# Out:
# Number ends with 7

# %% [markdown]
# ### 29. Check if the first character of a string is a vowel.

# %%
str=input("Enter the string: ")
if str[0]=="a" or str[0]=="e" or str[0]=="i" or str[0]=="o" or str[0]=="u":
    print("The first character of string is vowel")
else:
        print("The first character of string is consonant")   #apple
# Out:
# The first character of string is vowel

# %% [markdown]
# ### 30. Check if a number is within 1 to 100, else print “out of range

# %%
num=int(input("Enter the number: "))
if num>=1 and num<=100:
    print("Number is in 1 to 100")
else:
    print("Number is out of range")        #num=66
# Out:
# Number is in 1 to 100

# %% [markdown]
# ### 31. Check if a number is prime using if-else (simple logic allowed).

# %%
num=int(input("Enter the number: "))
if num <= 1:
    print("Not a prime number")
else:
    for i in range(2,num):
        if num%i==0:
            print("Not a prime number")
            break
    else:
        print("Prime number")           #num=31
# Out:
# Prime number

# %% [markdown]
# ### 32. Check if the last digit of a number is even or odd.

# %%
num=int(input("Enter a number: "))
last=num%10 
if last%2==0:
    print("Last digit is even")
else:
    print("Last digit is odd")      #num=6648
# Out:
# Last digit is even

# %% [markdown]
# ### 33. Check if the input is an integer or not (using string checks).

# %%
ip=input("Enter the number: ")
if ip.isdigit():
    print("Input is an integer")
else:
    if ip.startswith('-') and ip[1:].isdigit():
        print("Input is an integer")
    else:
        print("Input is not an integer")        #ip=-23
# Out:
# Input is an integer

# %% [markdown]
# ### 34. Check if three angles can form a valid triangle.

# %%
a=int(input("Angle 1st: "))
b=int(input("Angle 2nd: "))
c=int(input("Angle 3rd: "))
if a+b+c==180 and a>0 and b>0 and c>0:
    print("valid triangle")
else:
    print("not a triangle")         #a=60,b=60,c=60
# Out:
# valid triangle

# %% [markdown]
# ### 35. Check if two strings are anagrams (simple: check sorted equality).

# %%
str1 = input("String 1: ")
str2 = input("String 2: ")
if sorted(str1) == sorted(str2):
    print("Anagram")
else:
    print("Not an anagram")     #str1=hello,str2=hello
# Out:
# Anagram

# %% [markdown]
# ### 36. Determine the type of triangle using sides: acute, right, obtuse.

# %%
a,b,c=sorted(map(int,input("Enter 3 sides of a traingle: ").split()))
if a+b<=c:
    print("not a triangle")
elif a*a+b*b==c*c:
    print("right triangle")
elif a*a+b*b>c*c:
    print("acute triangle")
else:
    print("obtuse triangle")        #a b c=3 4 5
# Out:
# right triangle

# %% [markdown]
# ### 37. Check if a string is palindrome (case insensitive).

# %%
st=input("Enter a string: ")
if s==s[::-1]:
    print("Palindrome")
else:
    print("Not a palindrome")       #st=level
# Out:
# Palindrome

# %% [markdown]
# ### 38. Check if the first and last characters of a string are same.

# %%
st=input("Enter a string: ")
if s[0]==s[-1]:
    print("First and last characters are same")
else:
    print("Different")          #st=did
# Out:
# First and last characters are same

# %% [markdown]
# ### 39. Check if the sum of digits of a number is divisible by 3.

# %%
num=input("Enter a number: ") 
total=sum(int(i) for i in num)   
if total%3==0:                 
    print("Divisible by 3")
else:
    print("Not divisible by 3")         #num=12
# Out:
# Divisible by 3

# %% [markdown]
# ### 40. Check if a number is Armstrong (3-digit).

# %%
num=int(input("Enter a 3 digit number: "))
a=num//100       
b=(num//10)%10  
c=num%10          
ar=a**3+b**3+c**3
if ar==num:
    print("armstrong number")
else:
    print("not Armstrong")      #num=153
# Out:
# armstrong number

# %% [markdown]
# ### 41. Check if a number has exactly 3 digits.

# %%
num=int(input("Enter a number: "))
if 100<=num<=999:
    print("3-digit number")
else:
    print("Not a 3-digit number")           #num=555
# Out:
# 3-digit number

# %% [markdown]
# ### 42. Check if a number is perfect (sum of factors equals number).

# %%
num=int(input("Enter a number: "))
factor=sum(i for i in range(1, num) if num % i == 0)
if factor==num:
    print("Perfect number")
else:
    print("Not perfect")            #num=6
# Out:
# Perfect number

# %% [markdown]
# ### 43. Compare lengths of two strings and print which is longer.

# %%
str1=input("1st string: ")
str2=input("2nd string: ")
if len(str1)>len(str2):
    print("First string is longer than second")
elif len(str1)<len(str2):
    print("Second string is longer than first")
else:
    print("Both strings are equal in length")           #str1=abc, str2=xyz
# Out:
# Both strings are equal in length

# %% [markdown]
# ### 44. Check if a list contains duplicates.

# %%
lst = input("Enter list elements: ").split()
if len(lst)!=len(set(lst)):
    print("List has duplicates")
else:
    print("No duplicates")      #lst=t a n m a y e e
# Out:
# List has duplicates

# %% [markdown]
# ### 45. Check if a number is both prime AND even (only possible is 2).

# %%
num=int(input("Enter a number: "))
if num==2:
    print("Number is prime and even")
else:
    print("Not prime and even")     #num=2
# Out:
# Number is prime and even

# %% [markdown]
# ### 46. Print “YES” if any of the two numbers is zero else print “NO”.

# %%
a=int(input("Enter first number: "))
b=int(input("Enter second number: "))
if a==0 or b==0:
    print("YES")
else:
    print("NO")         #a=0,b=0
# Out:
# YES

# %% [markdown]
# ### 47. Check if two numbers have the same last digit.

# %%
a=int(input("First number: "))
b=int(input("Second number: "))
if a%10==b%10:
    print("Same last digit")
else:
    print("Different last digit")       #a=20,b=30
# Out:
# Same last digit

# %% [markdown]
# ### 48. Check if a password contains both letters and digits.

# %%
password = input("Enter password: ")
if any(c.isdigit() for c in password) and any(c.isalpha() for c in password):
    print("Valid password")
else:
    print("Invalid password")           #password=tanu6648
# Out:
# Valid password

# %% [markdown]
# ### 49. Check if a number is “lucky”: sum of first two digits equals last two digits.

# %%
num=input("Enter 4-digit number: ")
if len(num)==4 and (int(num[:2])==int(num[2:])):
    print("Lucky number")
else:
    print("Not lucky")          #num=3434
# Out:
# Lucky number

# %% [markdown]
# ### 50. Check if the absolute difference between two numbers is less than 10

# %%
a=int(input("1st number: "))
b=int(input("2nd number: "))
if abs(a-b)<10:
    print("Difference less than 10")
else:
    print("Difference 10 or more")      #a=4,b=2
# Out:
# Difference less than 10

# %% [markdown]
# ### 51. Write a program to check if a variable is an integer using isinstance().

# %%
var=10
if isinstance(var, int):
    print("Integer found")
else:
    print("Not an integer")
# Out:
# Integer found

# %% [markdown]
# ### 52. Check if a given input is a string using isinstance().

# %%
var = "hello"
if isinstance(var, str):
    print("String found")
else:
    print("Not a string")
# Out:
# String found

# %% [markdown]
# ### 53. Check if a variable is a float and print “Float value found”.

# %%
var = 5.5
if isinstance(var, float):
    print("Float value found")
else:
    print("Not float")
# Out:
# Float value found

# %% [markdown]
# ### 54. Check if a variable is a list; if yes, print its length.

# %%
var = [1,2,3]
if isinstance(var, list):
    print("Length of list:", len(var))
else:
    print("Not a list")
# Out:
# Length of list: 3

# %% [markdown]
# ### 55. Write a program to check if a variable is a tuple; if yes, print the first element.

# %%
var = (10, 20, 30)
if isinstance(var, tuple):
    print("First element:", var[0])
else:
    print("Not a tuple")
# Out:
# First element: 10

# %% [markdown]
# ### 56. Check if a variable is a dictionary; if yes, print all keys.

# %%
var = {"a":1, "b":2}
if isinstance(var, dict):
    print("Keys:", list(var.keys()))
else:
    print("Not a dictionary")
# Out:
# Keys: ['a', 'b']

# %% [markdown]
# ### 57. Check if a variable is a set; if yes, print the number of elements.

# %%
var = {1,2,3}
if isinstance(var, set):
    print("Number of elements:", len(var))
else:
    print("Not a set")
# Out:
# Number of elements: 3

# %% [markdown]
# ### 58. Check if a variable is a boolean and print “True/False detected”.

# %%
var = True
if isinstance(var, bool):
    print("Boolean detected")
else:
    print("Not a boolean")
# Out:
# Boolean detected

# %% [markdown]
# ### 59. Write a program to check if a variable is either int OR float (number check).

# %%
var = 5.5
if isinstance(var, (int, float)):
    print("Variable is a number")
else:
    print("Not a number")
# Out:
# Variable is a number

# %% [markdown]
# ### 60. Check if a variable is NOT a list (using not isinstance()), and print: “Not a list”.

# %%
var = 10
if not isinstance(var, list):
    print("Not a list")
else:
    print("It is a list")
# Out:
# Not a list
