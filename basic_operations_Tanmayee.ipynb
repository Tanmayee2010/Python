# %% [markdown]
# List Operations

# %%
lst1 = ["Tanmayee",20,10]
lst2 = ["Aditi",45,20]

# %%
print(lst1)
lst2[2]
# Out:
# ['Tanmayee', 20, 10]
# 20

# %%
print(lst1.index(20))
lst2.index('Aditi')
# Out:
# 1
# 0

# %%
lst1.append("Patil")

# %%
print(lst1)
lst2
# Out:
# ['Tanmayee', 20, 10, 'Patil']
# ['Aditi', 45, 20]

# %%
lst2.append("Kale")
print(lst2)
# Out:
# ['Aditi', 45, 20, 'Kale']

# %%
lst2.remove('Kale')
print(lst2)
# Out:
# ['Aditi', 45, 20]

# %%
lst1.copy()
# Out:
# ['Tanmayee', 20, 10, 'Patil']

# %%
lst1.count('Tanmayee')
# Out:
# 1

# %%
lst1.extend(lst2)

# %%
lst1
# Out:
# ['Tanmayee', 20, 10, 'Patil', 'Aditi', 45, 20, 'Kale']

# %%
lst1.index('Patil')
# Out:
# 3

# %%
lst1.insert(4,'Arya')

# %%
lst1
# Out:
# ['Tanmayee', 20, 10, 'Patil', 'Arya', 'Aditi', 45, 20, 'Kale']

# %%
lst1.pop(4)
# Out:
# 'Arya'

# %%
lst1
# Out:
# ['Tanmayee', 20, 10, 'Patil', 'Aditi', 45, 20, 'Kale']

# %%
lst1.reverse()
lst1
# Out:
# ['Kale', 20, 45, 'Aditi', 'Patil', 10, 20, 'Tanmayee']

# %%
lst3 = [1,5,2,7,3]

# %%
lst3.sort()

# %%
print(lst3)
# Out:
# [1, 2, 3, 5, 7]

# %% [markdown]
# Tuple Operations

# %%
tp = (10,20,30,40,50,20)
tp
# Out:
# (10, 20, 30, 40, 50, 20)

# %%
tp.count(20)
# Out:
# 2

# %%
tp.index(20)
# Out:
# 1

# %% [markdown]
# Set Operations

# %%
st = {'python',20,30}
st
# Out:
# {20, 30, 'python'}

# %%
st.add("hive")

# %%
st
# Out:
# {20, 30, 'hive', 'python'}

# %%
st.copy()
# Out:
# {20, 30, 'hive', 'python'}

# %%
st2 = {'had0op',23,45,20}
st2
# Out:
# {20, 23, 45, 'had0op'}

# %%
st.difference(st2)
# Out:
# {20, 30, 'hive', 'python'}

# %%
st.difference_update(st2)

# %%
st2.discard(23)

# %%
st2
# Out:
# {45, 'had0op'}

# %%
st.intersection(st2)
# Out:
# {20}

# %%
st.isdisjoint(st2)
# Out:
# False

# %%
st.issubset(st2)
# Out:
# False

# %%
st.issuperset(st2)
# Out:
# False

# %%
st3 ={1,2,3}
st3.pop()
# Out:
# 1

# %%
st3
# Out:
# {1}

# %%
st4 = {1,2,3,4,5,6}
st4
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
st4.remove(6)
st4
# Out:
# {1, 2, 3, 4, 5}

# %%
st3.symmetric_difference(st4)
# Out:
# {1, 2, 3, 4, 5}

# %%
st3.symmetric_difference_update(st4)

# %%
st3.union(st4)
# Out:
# {1, 2, 3, 4, 5}

# %%
st3.update(st4)

# %%
st3
# Out:
# {1, 2, 20, 3, 30, 4, 5, 'hive', 'python'}

# %% [markdown]
# Dictionary Operations

# %%
dict = {"Name":"Tanmayee", "Degree":"B.tech"}
dict
# Out:
# {'Name': 'Tanmayee', 'Degree': 'B.tech'}

# %%
dict.get("Name")
# Out:
# 'Tanmayee'

# %%
dict.items()
# Out:
# dict_items([('Name', 'Tanmayee'), ('Degree', 'B.tech')])

# %%
dict.keys()
# Out:
# dict_keys(['Name', 'Degree'])

# %%
dict.popitem()
# Out:
# ('Degree', 'B.tech')

# %%
dict
# Out:
# {'Name': 'Tanmayee'}

# %%
dict.copy()  #shallow copy and Deep copy
# Out:
# {'Name': 'Tanmayee'}

# %%
dict.fromkeys("Name")
# Out:
# {'N': None, 'a': None, 'm': None, 'e': None}

# %%
dict2 ={"Degree":"B.tech","Year":2025}
dict2
# Out:
# {'Degree': 'B.tech', 'Year': 2025}

# %%
dict.update(dict2)

# %%
dict
# Out:
# {'Name': 'Tanmayee', 'Degree': 'B.tech', 'Year': 2025}

# %%
dict.values()
# Out:
# dict_values(['Tanmayee', 'B.tech', 2025])

# %% [markdown]
# String Operations

# %%
str = 'Tanmayee'
str2 = 'Patil'

# %%
print(str)
print(str2)
# Out:
# Tanmayee
# Patil

# %%
str.upper()
# Out:
# 'TANMAYEE'

# %%
str.capitalize()
# Out:
# 'Tanmayee'

# %%
str2.casefold()
# Out:
# 'patil'

# %%
str2.count("Tanmayee")
# Out:
# 0

# %%
str2.endswith('j')
# Out:
# False

# %%
str2.split()
# Out:
# ['Patil']

# %%
str2.upper()
# Out:
# 'PATIL'

# %%
str2.swapcase()
# Out:
# 'pATIL'

# %%
str2.startswith('p')
# Out:
# False

# %%
str2.istitle()
# Out:
# True
