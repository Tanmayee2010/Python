# %% [markdown]
# # Basic List Operations

# %% [markdown]
# 1. Create a list of 5 numbers and add a new number to the end.

# %%
lst1=[10,20,30,40,50]
lst1.append(60)
lst1
# Out:
# [10, 20, 30, 40, 50, 60]

# %% [markdown]
# 2. Make a list of fruits and insert a fruit at the second position.

# %%
lst2=["Mango","Orange","Apple","Banana"]
lst2.insert(1, "Pineapple")
lst2
# Out:
# ['Mango', 'Pineapple', 'Orange', 'Apple', 'Banana']

# %% [markdown]
# 3. Create a list of names and remove one name from the list.

# %%
lst3=["Tanmayee","Aditi","Arya","Sayali","Geeta"]
lst3.remove("Arya")
lst3
# Out:
# ['Tanmayee', 'Aditi', 'Sayali', 'Geeta']

# %% [markdown]
# 4. Create a list of 4 items and change the value at index 2.

# %%
lst3=["Tanmayee","Aditi","Arya","Sayali","Geeta"]
lst3[2]="Vaishnavi"
lst3
# Out:
# ['Tanmayee', 'Aditi', 'Vaishnavi', 'Sayali', 'Geeta']

# %% [markdown]
# 5. Make a list of numbers and print only the first three elements.

# %%
lst4=[1,2,3,4,5,6]
lst4[0:3]
# Out:
# [1, 2, 3]

# %% [markdown]
# 6. Create a list of colors and find the index of a specific color.

# %%
lst5=["Pink","Blue","White","Black"]
lst5.index("Blue")
# Out:
# 1

# %% [markdown]
# 7. Create a list of 10 numbers and print how many times “5” appears.

# %%
lst6=[1,2,5,4,5,7,8,9,5,2]
lst6.count(5)
# Out:
# 3

# %% [markdown]
# 8. Make a list of 6 items and delete the item at index 3.

# %%
lst7=["Tanmayee","Aditi","Arya","Sayali","Geeta","Sejal"]
del lst7[3]
lst7
# Out:
# ['Tanmayee', 'Aditi', 'Arya', 'Geeta', 'Sejal']

# %% [markdown]
# 9. Create a list of animals and add three more animals using extend().

# %%
lst8=["Cat","Dog","Horse","Lion"]
lst9=["Tiger","Mouse","Cow"]
lst8.extend(lst9)
lst8
# Out:
# ['Cat', 'Dog', 'Horse', 'Lion', 'Tiger', 'Mouse', 'Cow']

# %% [markdown]
# 10. Create a list and remove the last item using pop().

# %%
lst11=["Cat","Dog","Horse","Lion"]
lst11.pop(3)
# Out:
# 'Lion'

# %% [markdown]
# 11. Create a list of prices and sort them in ascending order.

# %%
prices=[60000,50000,30000,40000,70000,10000]
prices.sort()
prices
# Out:
# [10000, 30000, 40000, 50000, 60000, 70000]

# %% [markdown]
# 12. Make a list of countries and reverse the order of the list.

# %%
countries=["India","America","Nepal","Russia","Japan"]
countries.reverse()
countries
# Out:
# ['Japan', 'Russia', 'Nepal', 'America', 'India']

# %% [markdown]
# 13. Create a list of words and check if “apple” is in the list.

# %%
fruits=["Mango","Orange","Apple","Banana"]
"Apple" in fruits
# Out:
# True

# %% [markdown]
# 14. Create a list of numbers and print the largest and smallest number.

# %%
num=[23,45,98,23,44,65,76]
print(max(num))
print(min(num))
# Out:
# 98
# 23

# %% [markdown]
# 15. Make a list of 5 items and print each item using a loop.

# %%
num=[23,45,98,65,76]
for i in num:
    print(i)
# Out:
# 23
# 45
# 98
# 65
# 76

# %% [markdown]
# 16. Create two lists and combine them into one list.

# %%
ls1=["Tanu","Panu","Aru"]
ls2=["Tanshu","Varun","Hiten"]
ls1.extend(ls2)
ls1
# Out:
# ['Tanu', 'Panu', 'Aru', 'Tanshu', 'Varun', 'Hiten']

# %% [markdown]
# 17. Make a list and replace the last item with a new value.

# %%
ls3=[1,2,3,4,5,6,7]
ls3[6]=8
ls3
# Out:
# [1, 2, 3, 4, 5, 6, 8]

# %% [markdown]
# 18. Create a list of numbers and print only the even numbers.

# %%
ls4=[1,2,3,4,5,6,7,8]
for i in ls4:
    if i%2==0:
        print(i)
# Out:
# 2
# 4
# 6
# 8

# %% [markdown]
# 19. Create a list and clear all items from the list.

# %%
ls3=[1,2,3,4,5,6,7]
ls3.clear()
ls3
# Out:
# []

# %% [markdown]
# 20. Create a list of 5 values and copy it into another list.

# %%
list1=[1,2,3,4,5]
list2=list1.copy()
list2
# Out:
# [1, 2, 3, 4, 5]
